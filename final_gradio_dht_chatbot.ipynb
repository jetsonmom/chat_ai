# %%
# !pip install gradio
# Out:
# Collecting gradio
#   Using cached gradio-4.44.1-py3-none-any.whl (18.1 MB)
# Collecting pydub
#   Using cached pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Collecting typer<1.0,>=0.12
#   Using cached typer-0.15.1-py3-none-any.whl (44 kB)
# Collecting pyyaml<7.0,>=5.0
#   Using cached PyYAML-6.0.2-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (728 kB)
# Requirement already satisfied: packaging in ./chatbot_env/lib/python3.8/site-packages (from gradio) (24.2)
# Collecting pydantic>=2.0
#   Using cached pydantic-2.10.5-py3-none-any.whl (431 kB)
# Collecting urllib3~=2.0
#   Using cached urllib3-2.2.3-py3-none-any.whl (126 kB)
# Collecting pillow<11.0,>=8.0
#   Using cached pillow-10.4.0-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (4.3 MB)
# Collecting jinja2<4.0
#   Using cached jinja2-3.1.5-py3-none-any.whl (134 kB)
# Collecting importlib-resources<7.0,>=1.3
#   Using cached importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Requirement already satisfied: typing-extensions~=4.0 in ./chatbot_env/lib/python3.8/site-packages (from gradio) (4.12.2)
# Collecting aiofiles<24.0,>=22.0
#   Using cached aiofiles-23.2.1-py3-none-any.whl (15 kB)
# Collecting uvicorn>=0.14.0
#   Using cached uvicorn-0.33.0-py3-none-any.whl (62 kB)
# Collecting tomlkit==0.12.0
#   Using cached tomlkit-0.12.0-py3-none-any.whl (37 kB)
# Collecting ruff>=0.2.2
#   Downloading ruff-0.9.2-py3-none-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (11.8 MB)
#      |████████████████████████████████| 11.8 MB 53 kB/s  eta 0:00:01
# Collecting orjson~=3.0
#   Using cached orjson-3.10.14-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (135 kB)
# Collecting gradio-client==1.3.0
#   Using cached gradio_client-1.3.0-py3-none-any.whl (318 kB)
# Collecting python-multipart>=0.0.9
#   Using cached python_multipart-0.0.20-py3-none-any.whl (24 kB)
# Collecting matplotlib~=3.0
#   Using cached matplotlib-3.7.5-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (11.4 MB)
# Collecting ffmpy
#   Using cached ffmpy-0.5.0-py3-none-any.whl (6.0 kB)
# Collecting huggingface-hub>=0.19.3
#   Using cached huggingface_hub-0.27.1-py3-none-any.whl (450 kB)
# Collecting pandas<3.0,>=1.0
#   Using cached pandas-2.0.3-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (11.7 MB)
# Collecting anyio<5.0,>=3.0
#   Using cached anyio-4.5.2-py3-none-any.whl (89 kB)
# Collecting numpy<3.0,>=1.0
#   Using cached numpy-1.24.4-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (14.0 MB)
# Collecting fastapi<1.0
#   Using cached fastapi-0.115.6-py3-none-any.whl (94 kB)
# Collecting markupsafe~=2.0
#   Using cached MarkupSafe-2.1.5-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (26 kB)
# Collecting semantic-version~=2.0
#   Using cached semantic_version-2.10.0-py2.py3-none-any.whl (15 kB)
# Collecting httpx>=0.24.1
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting websockets<13.0,>=10.0
#   Using cached websockets-12.0-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (131 kB)
# Collecting fsspec
#   Using cached fsspec-2024.12.0-py3-none-any.whl (183 kB)
# Collecting idna>=2.8
#   Using cached idna-3.10-py3-none-any.whl (70 kB)
# Collecting sniffio>=1.1
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting exceptiongroup>=1.0.2
#   Using cached exceptiongroup-1.2.2-py3-none-any.whl (16 kB)
# Collecting starlette<0.42.0,>=0.40.0
#   Using cached starlette-0.41.3-py3-none-any.whl (73 kB)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.7-py3-none-any.whl (78 kB)
# Collecting certifi
#   Using cached certifi-2024.12.14-py3-none-any.whl (164 kB)
# Collecting h11<0.15,>=0.13
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting tqdm>=4.42.1
#   Using cached tqdm-4.67.1-py3-none-any.whl (78 kB)
# Collecting requests
#   Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# Collecting filelock
#   Using cached filelock-3.16.1-py3-none-any.whl (16 kB)
# Requirement already satisfied: zipp>=3.1.0 in ./chatbot_env/lib/python3.8/site-packages (from importlib-resources<7.0,>=1.3->gradio) (3.20.2)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.55.3-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (4.7 MB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.1.4-py3-none-any.whl (104 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.7-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (1.4 MB)
# Requirement already satisfied: python-dateutil>=2.7 in ./chatbot_env/lib/python3.8/site-packages (from matplotlib~=3.0->gradio) (2.9.0.post0)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.1.1-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (285 kB)
# Collecting pytz>=2020.1
#   Using cached pytz-2024.2-py2.py3-none-any.whl (508 kB)
# Collecting tzdata>=2022.1
#   Using cached tzdata-2024.2-py2.py3-none-any.whl (346 kB)
# Collecting pydantic-core==2.27.2
#   Using cached pydantic_core-2.27.2-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (1.8 MB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Requirement already satisfied: six>=1.5 in ./chatbot_env/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.17.0)
# Collecting rich>=10.11.0
#   Using cached rich-13.9.4-py3-none-any.whl (242 kB)
# Collecting click>=8.0.0
#   Using cached click-8.1.8-py3-none-any.whl (98 kB)
# Collecting shellingham>=1.3.0
#   Using cached shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./chatbot_env/lib/python3.8/site-packages (from rich>=10.11.0->typer<1.0,>=0.12->gradio) (2.19.1)
# Collecting markdown-it-py>=2.2.0
#   Using cached markdown_it_py-3.0.0-py3-none-any.whl (87 kB)
# Collecting mdurl~=0.1
#   Using cached mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.4.1-cp38-cp38-manylinux_2_17_aarch64.manylinux2014_aarch64.whl (140 kB)
# Installing collected packages: urllib3, sniffio, mdurl, idna, h11, exceptiongroup, charset-normalizer, certifi, tqdm, requests, pyyaml, pydantic-core, numpy, markdown-it-py, httpcore, fsspec, filelock, anyio, annotated-types, websockets, tzdata, starlette, shellingham, rich, pytz, pyparsing, pydantic, pillow, markupsafe, kiwisolver, importlib-resources, huggingface-hub, httpx, fonttools, cycler, contourpy, click, uvicorn, typer, tomlkit, semantic-version, ruff, python-multipart, pydub, pandas, orjson, matplotlib, jinja2, gradio-client, ffmpy, fastapi, aiofiles, gradio
# Successfully installed aiofiles-23.2.1 annotated-types-0.7.0 anyio-4.5.2 certifi-2024.12.14 charset-normalizer-3.4.1 click-8.1.8 contourpy-1.1.1 cycler-0.12.1 exceptiongroup-1.2.2 fastapi-0.115.6 ffmpy-0.5.0 filelock-3.16.1 fonttools-4.55.3 fsspec-2024.12.0 gradio-4.44.1 gradio-client-1.3.0 h11-0.14.0 httpcore-1.0.7 httpx-0.28.1 huggingface-hub-0.27.1 idna-3.10 importlib-resources-6.4.5 jinja2-3.1.5 kiwisolver-1.4.7 markdown-it-py-3.0.0 markupsafe-2.1.5 matplotlib-3.7.5 mdurl-0.1.2 numpy-1.24.4 orjson-3.10.14 pandas-2.0.3 pillow-10.4.0 pydantic-2.10.5 pydantic-core-2.27.2 pydub-0.25.1 pyparsing-3.1.4 python-multipart-0.0.20 pytz-2024.2 pyyaml-6.0.2 requests-2.32.3 rich-13.9.4 ruff-0.9.2 semantic-version-2.10.0 shellingham-1.5.4 sniffio-1.3.1 starlette-0.41.3 tomlkit-0.12.0 tqdm-4.67.1 typer-0.15.1 tzdata-2024.2 urllib3-2.2.3 uvicorn-0.33.0 websockets-12.0
# WARNING: You are using pip version 21.1.1; however, version 24.3.1 is available.
# You should consider upgrading via the '/home/chat/chatbot_env/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import serial
import time
import threading
import gradio as gr
from typing import Dict, List, Optional

class DHT11Assistant:
    def __init__(self):
        # 시스템 메시지와 사용 가능한 함수들 정의
        self.messages = [
            {
                "role": "system",
                "content": "나는 젯슨맘입니다. 온습도 센서의 데이터를 읽고 응답하는 도우미입니다."
            }
        ]
        
        self.functions = {
            "get_temperature": {
                "name": "get_temperature",
                "description": "현재 온도값을 가져옵니다",
                "parameters": {
                    "type": "object",
                    "properties": {},
                    "required": []
                }
            },
            "get_humidity": {
                "name": "get_humidity",
                "description": "현재 습도값을 가져옵니다",
                "parameters": {
                    "type": "object",
                    "properties": {},
                    "required": []
                }
            }
        }
        
        # 센서 관련 변수
        self.serial_port = None
        self.current_temp = None
        self.current_humidity = None
        self.running = True

    def get_temperature(self) -> Dict:
        """온도 데이터를 반환하는 함수"""
        if self.current_temp is None:
            return {"status": "error", "message": "온도 데이터를 아직 받지 못했습니다"}
        return {"status": "success", "temperature": self.current_temp}

    def get_humidity(self) -> Dict:
        """습도 데이터를 반환하는 함수"""
        if self.current_humidity is None:
            return {"status": "error", "message": "습도 데이터를 아직 받지 못했습니다"}
        return {"status": "success", "humidity": self.current_humidity}

    def start_serial(self):
        """시리얼 포트 초기화"""
        try:
            if self.serial_port is not None:
                self.serial_port.close()
            
            self.serial_port = serial.Serial('/dev/ttyUSB1', 115200, timeout=1)
            print("시리얼 포트 연결 성공!")
            time.sleep(2)
            return True
        except Exception as e:
            print(f"시리얼 포트 연결 실패: {e}")
            return False

    def read_sensor_data(self):
        """센서 데이터 읽기 루프"""
        while self.running:
            try:
                if self.serial_port and self.serial_port.in_waiting:
                    line = self.serial_port.readline()
                    text = line.decode('utf-8').strip()
                    print("받은 데이터:", text)
                    
                    if text and ',' in text:
                        temp_str, humid_str = text.split(',')
                        try:
                            self.current_temp = int(temp_str)
                            self.current_humidity = int(humid_str)
                            print(f"파싱된 데이터 - 온도: {self.current_temp}, 습도: {self.current_humidity}")
                        except ValueError:
                            print("숫자 변환 실패")
            except Exception as e:
                print(f"데이터 읽기 오류: {e}")
            time.sleep(0.1)

    def process_message(self, user_message: str) -> str:
        """사용자 메시지 처리"""
        self.messages.append({"role": "user", "content": user_message})
    
        if '온도' in user_message:
            function_name = "get_temperature"
            response = self.get_temperature()
            if response["status"] == "success":
                answer = f"우리 집의 현재 온도는 {response['temperature']}°C예요~"
            else:
                answer = "아직 온도 데이터를 받지 못했네요. 잠시만 기다려주세요!"
            
        elif '습도' in user_message:
            function_name = "get_humidity"
            response = self.get_humidity()
            if response["status"] == "success":
                answer = f"현재 습도는 {response['humidity']}%입니다~"
            else:
                answer = "아직 습도 데이터를 읽지 못했어요. 조금만 기다려주세요!"
            
        else:
            temp_response = self.get_temperature()
            humid_response = self.get_humidity()
            if temp_response["status"] == "success" and humid_response["status"] == "success":
               answer = f"우리 집의 온도는 {temp_response['temperature']}°C이고, 습도는 {humid_response['humidity']}%예요~"
            else:
                answer = "센서에서 데이터를 읽어오는 중이에요. 잠시만 기다려주세요!"

        # 응답 저장
        self.messages.append({
            "role": "assistant",
            "content": answer,
            "function_call": {
                "name": function_name if '온도' in user_message or '습도' in user_message else "get_all",
                "arguments": "{}"
            }
        })
    
        return answer

def create_chat_interface():
    assistant = DHT11Assistant()
    
    if assistant.start_serial():
        thread = threading.Thread(target=assistant.read_sensor_data, daemon=True)
        thread.start()
        
        demo = gr.Interface(
            fn=assistant.process_message,
            inputs=gr.Textbox(placeholder="질문을 입력하세요 (예: 지금 온도는 어때요?)"),
            outputs="text",
            title="온습도 센서 챗봇",
            description="젯슨맘의 온습도 봇입니다. 온도나 습도에 대해 물어보세요!"
        )
        
        demo.launch(share=False)
    else:
        print("시리얼 포트 초기화 실패")

if __name__ == "__main__":
    create_chat_interface()
# Out:
# 시리얼 포트 연결 성공!
# Running on local URL:  http://127.0.0.1:7866
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7866/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 받은 데이터: 2154
# 받은 데이터: 2,54
# 파싱된 데이터 - 온도: 2, 습도: 54
# 받은 데이터: 1,5
# 파싱된 데이터 - 온도: 1, 습도: 5
# 받은 데이터: 2154
# 받은 데이터: ,4
# 숫자 변환 실패
# 받은 데이터: ,5
# 숫자 변환 실패
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터:
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 2,54
# 파싱된 데이터 - 온도: 2, 습도: 54
# 받은 데이터: 2154
# 받은 데이터: 2,54
# 파싱된 데이터 - 온도: 2, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 1
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 15
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 1,
# 숫자 변환 실패
# 받은 데이터: 154
# 받은 데이터: 2
# 받은 데이터: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 1,5
# 파싱된 데이터 - 온도: 1, 습도: 5
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 2,54
# 파싱된 데이터 - 온도: 2, 습도: 54
# 받은 데이터: 14
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21
# 받은 데이터: 2,54
# 파싱된 데이터 - 온도: 2, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 24
# 받은 데이터:
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 2,5
# 파싱된 데이터 - 온도: 2, 습도: 5
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 4
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 2
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 25
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 2
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 214
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 15
# 받은 데이터: 15
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: ,4
# 숫자 변환 실패
# 받은 데이터:
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: ,
# 숫자 변환 실패
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 1,5
# 파싱된 데이터 - 온도: 1, 습도: 5
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 25
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: ,5
# 숫자 변환 실패
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 15
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 21,4
# 파싱된 데이터 - 온도: 21, 습도: 4
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 1
# 받은 데이터: ,4
# 숫자 변환 실패
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54

# %%
import serial
import time
import threading
import gradio as gr
from typing import Dict, List, Optional

class DHT11Assistant:
    def __init__(self):
        # 시스템 메시지와 사용 가능한 함수들 정의
        self.messages = [
            {
                "role": "system",
                "content": "나는 젯슨맘입니다. 온습도 센서의 데이터를 읽고 응답하는 도우미입니다."
            }
        ]
        
        self.functions = {
            "get_temperature": {
                "name": "get_temperature",
                "description": "현재 온도값을 가져옵니다",
                "parameters": {
                    "type": "object",
                    "properties": {},
                    "required": []
                }
            },
            "get_humidity": {
                "name": "get_humidity",
                "description": "현재 습도값을 가져옵니다",
                "parameters": {
                    "type": "object",
                    "properties": {},
                    "required": []
                }
            }
        }
        
        # 센서 관련 변수
        self.serial_port = None
        self.current_temp = None
        self.current_humidity = None
        self.running = True

    def get_temperature(self) -> Dict:
        """온도 데이터를 반환하는 함수"""
        if self.current_temp is None:
            return {"status": "error", "message": "온도 데이터를 아직 받지 못했습니다"}
        return {"status": "success", "temperature": self.current_temp}

    def get_humidity(self) -> Dict:
        """습도 데이터를 반환하는 함수"""
        if self.current_humidity is None:
            return {"status": "error", "message": "습도 데이터를 아직 받지 못했습니다"}
        return {"status": "success", "humidity": self.current_humidity}

    def start_serial(self):
        """시리얼 포트 초기화"""
        try:
            if self.serial_port is not None:
                self.serial_port.close()
            
            self.serial_port = serial.Serial('/dev/ttyUSB1', 115200, timeout=1)
            print("시리얼 포트 연결 성공!")
            time.sleep(2)
            return True
        except Exception as e:
            print(f"시리얼 포트 연결 실패: {e}")
            return False

    def read_sensor_data(self):
        """센서 데이터 읽기 루프"""
        while self.running:
            try:
                if self.serial_port and self.serial_port.in_waiting:
                    line = self.serial_port.readline()
                    text = line.decode('utf-8').strip()
                    print("받은 데이터:", text)
                    
                    if text and ',' in text:
                        temp_str, humid_str = text.split(',')
                        try:
                            self.current_temp = int(temp_str)
                            self.current_humidity = int(humid_str)
                            print(f"파싱된 데이터 - 온도: {self.current_temp}, 습도: {self.current_humidity}")
                        except ValueError:
                            print("숫자 변환 실패")
            except Exception as e:
                print(f"데이터 읽기 오류: {e}")
            time.sleep(0.1)

    def process_message(self, user_message: str) -> str:
        """사용자 메시지 처리"""
        self.messages.append({"role": "user", "content": user_message})
        
        if '안녕' in user_message:
            return "안녕하세요! 오늘 즐거우셨나요?"
    
        if '온도' in user_message:
            function_name = "get_temperature"
            response = self.get_temperature()
            if response["status"] == "success":
                answer = f"우리 집의 현재 온도는 {response['temperature']}°C예요~"
            else:
                answer = "아직 온도 데이터를 받지 못했네요. 잠시만 기다려주세요!"
            
        elif '습도' in user_message:
            function_name = "get_humidity"
            response = self.get_humidity()
            if response["status"] == "success":
                answer = f"현재 습도는 {response['humidity']}%입니다~"
            else:
                answer = "아직 습도 데이터를 읽지 못했어요. 조금만 기다려주세요!"
            
        else:
            temp_response = self.get_temperature()
            humid_response = self.get_humidity()
            if temp_response["status"] == "success" and humid_response["status"] == "success":
               answer = f"우리 집의 온도는 {temp_response['temperature']}°C이고, 습도는 {humid_response['humidity']}%예요~"
            else:
                answer = "센서에서 데이터를 읽어오는 중이에요. 잠시만 기다려주세요!"

        # 응답 저장
        self.messages.append({
            "role": "assistant",
            "content": answer,
            "function_call": {
                "name": function_name if '온도' in user_message or '습도' in user_message else "get_all",
                "arguments": "{}"
            }
        })
    
        return answer

def create_chat_interface():
    assistant = DHT11Assistant()
    
    if assistant.start_serial():
        thread = threading.Thread(target=assistant.read_sensor_data, daemon=True)
        thread.start()
        
        # Gradio 인터페이스 생성
        with gr.Blocks() as demo:
            gr.Markdown("# 온습도 센서 챗봇")
            gr.Markdown("### 안녕하세요! 나는 젯슨맘입니다. 온습도 센서의 데이터를 읽고 응답하는 도우미입니다.")
            
            gr.Interface(
                fn=assistant.process_message,
                inputs=gr.Textbox(placeholder="질문을 입력하세요 (예: 지금 온도는 어때요?)"),
                outputs="text",
                description="온도나 습도에 대해 물어보세요!"
            )
        
        demo.launch(share=False)
    else:
        print("시리얼 포트 초기화 실패")

if __name__ == "__main__":
    create_chat_interface()
# Out:
# 시리얼 포트 연결 성공!
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# Running on local URL:  http://127.0.0.1:7868
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7868/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# 데이터 읽기 오류: device reports readiness to read but returned no data (device disconnected or multiple access on port?)
# 받은 데이터: 21,5
# 파싱된 데이터 - 온도: 21, 습도: 5
# 받은 데이터: 21
# 받은 데이터:
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: ,4
# 숫자 변환 실패
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
# 받은 데이터: 2,5
# 파싱된 데이터 - 온도: 2, 습도: 5
# 받은 데이터: 21,54
# 파싱된 데이터 - 온도: 21, 습도: 54
